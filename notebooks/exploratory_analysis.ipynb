# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/data_csv.csv")
df.head()
# Out:
#    Temperature (K)  Grain Size (nm)  Fe %   Ni %   Cr %   Co %   Cu %  \
# 0              200             17.2  0.10  0.225  0.225  0.225  0.225
# 1              200             17.2  0.12  0.220  0.220  0.220  0.220
# 2              200             17.2  0.14  0.215  0.215  0.215  0.215
# 3              200             17.2  0.16  0.210  0.210  0.210  0.210
# 4              200             17.2  0.18  0.205  0.205  0.205  0.205
#
#    Strain Rate (Strain/ps)  Young's Modulus (GPa)  Yield Strength (MPa)  \
# 0                    0.004                    165                  3304
# 1                    0.004                    164                  3410
# 2                    0.004                    161                  3593
# 3                    0.004                    155                  3970
# 4                    0.004                    162                  3420
#
#    Ultimate Tensile Strength (MPa)
# 0                             5396
# 1                             5168
# 2                             5281
# 3                             5425
# 4                             5392

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Temperature (K)                  918 non-null    int64
#  1   Grain Size (nm)                  918 non-null    float64
#  2   Fe %                             918 non-null    float64
#  3   Ni %                             918 non-null    float64
#  4   Cr %                             918 non-null    float64
#  5   Co %                             918 non-null    float64
#  6   Cu %                             918 non-null    float64
#  7   Strain Rate (Strain/ps)          918 non-null    float64
#  8   Young's Modulus (GPa)            918 non-null    int64
#  9   Yield Strength (MPa)             918 non-null    int64
#  10  Ultimate Tensile Strength (MPa)  918 non-null    int64
# dtypes: float64(7), int64(4)
# memory usage: 79.0 KB

# %%
df.describe()
# Out:
#        Temperature (K)  Grain Size (nm)        Fe %        Ni %        Cr %  \
# count       918.000000       918.000000  918.000000  918.000000  918.000000
# mean        300.000000        14.700000    0.200000    0.200000    0.200000
# std          81.694166         1.900158    0.032857    0.032857    0.032857
# min         200.000000        12.600000    0.100000    0.100000    0.100000
# 25%         200.000000        12.600000    0.180000    0.180000    0.180000
# 50%         300.000000        14.300000    0.200000    0.200000    0.200000
# 75%         400.000000        17.200000    0.220000    0.220000    0.220000
# max         400.000000        17.200000    0.300000    0.300000    0.300000
#
#              Co %        Cu %  Strain Rate (Strain/ps)  Young's Modulus (GPa)  \
# count  918.000000  918.000000                918.00000             918.000000
# mean     0.200000    0.200000                  0.02200             152.066449
# std      0.032857    0.032857                  0.01801              20.142918
# min      0.100000    0.100000                  0.00400             112.000000
# 25%      0.180000    0.180000                  0.00400             129.000000
# 50%      0.200000    0.200000                  0.02200             158.000000
# 75%      0.220000    0.220000                  0.04000             166.000000
# max      0.300000    0.300000                  0.04000             194.000000
#
#        Yield Strength (MPa)  Ultimate Tensile Strength (MPa)
# count            918.000000                       918.000000
# mean            3748.547930                      7089.532680
# std              732.829268                      2105.192052
# min             2514.000000                      4391.000000
# 25%             3128.000000                      5030.250000
# 50%             3633.000000                      6880.000000
# 75%             4180.750000                      8995.000000
# max             5388.000000                     10557.000000

# %%
df.isnull().sum()
# Out:
# Temperature (K)                    0
# Grain Size (nm)                    0
# Fe %                               0
# Ni %                               0
# Cr %                               0
# Co %                               0
# Cu %                               0
# Strain Rate (Strain/ps)            0
# Young's Modulus (GPa)              0
# Yield Strength (MPa)               0
# Ultimate Tensile Strength (MPa)    0
# dtype: int64

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
df.hist(figsize=(14, 10))
plt.tight_layout()
plt.show()
